# %% [markdown]
# <a href="https://colab.research.google.com/github/mamta85/Plan_1/blob/main/Untitled78_need_to_improve.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U sentence-transformers umap-learn
from google.colab import files
import pandas as pd

uploaded = files.upload()  # Upload your cleaned reviews file
filename = next(iter(uploaded))
data = pd.read_csv(filename)

# Take first 50,000 reviews
data = data.head(50000)
reviews = data['content'].fillna('').astype(str)
import re

issue_keywords = {
    'bug': ['bug', 'bugs', 'glitch', 'glitches'],
    'error': ['error', 'errors', 'crash', 'crashes', 'fail'],
    'problem': ['problem', 'problems', 'issue', 'issues'],
    'ads': ['ad', 'ads', 'advertisement'],
    'login': ['login', 'log in', 'sign in', 'signin'],
    'payment': ['payment', 'paid', 'charge', 'billing', 'refund'],
    'performance': ['slow', 'lag', 'hang', 'freeze'],
    'update': ['update', 'version', 'patch'],
    'ui/ux': ['interface', 'design', 'layout', 'navigation', 'screen']
}

def tag_issue(review):
    review = review.lower()
    for label, keywords in issue_keywords.items():
        for kw in keywords:
            if re.search(r'\b' + re.escape(kw) + r'\b', review):
                return label
    return 'other'

data['issue_tag'] = reviews.apply(tag_issue)
import umap.umap_ as umap
import numpy as np

model = SentenceTransformer('all-MiniLM-L6-v2')
embeddings = model.encode(reviews.tolist(), show_progress_bar=True)

data['embedding'] = list(embeddings)

# Append embeddings to DataFrame
embedding_array = np.array(data['embedding'].tolist())

# UMAP
umap_2d = umap.UMAP(n_neighbors=15, min_dist=0.05, metric='cosine').fit_transform(embedding_array)
data['x'] = umap_2d[:, 0]
data['y'] = umap_2d[:, 1]
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(14, 10))
sns.scatterplot(
    data=data,
    x='x', y='y',
    hue='issue_tag',
    palette='tab10',
    s=12,
    edgecolor='none',
    alpha=0.7
)
plt.title("Clusters of User Reviews by Issue Type (50,000 Reviews)", fontsize=16)
plt.xlabel("UMAP Dimension 1")
plt.ylabel("UMAP Dimension 2")
plt.legend(title="Issue Type", bbox_to_anchor=(1.05, 1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.1/90.1 kB 3.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: umap-learn
#     Found existing installation: umap-learn 0.5.8
#     Uninstalling umap-learn-0.5.8:
#       Successfully uninstalled umap-learn-0.5.8
# ...
#      <input type="file" id="files-d35235d3-1a84-460a-a843-865f9609b0e9" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d35235d3-1a84-460a-a843-865f9609b0e9">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# ...

# %%
# Define the issue_keywords dictionary
issue_keywords = {
    'bug/error': ['bug', 'error', 'crash', 'freeze', 'glitch', 'problem', 'issue'],
    'feature request': ['feature', 'request', 'add', 'want', 'need', 'missing'],
    'ui/ux': ['interface', 'design', 'layout', ' fácil', 'confusing', 'intuitive'],
    'performance': ['slow', 'fast', 'lag', 'speed', 'responsive'],
    'payment/subscription': ['pay', 'price', 'cost', 'subscription', 'premium', 'free', 'trial'],
    'update': ['update', 'new version', 'after update', ' broke'],
    'other': [] # Default category
}
